# %% [raw]
#                                                             Année validée ou non ?
#
# 🧧 La situation
#
# L'évaluation de l'année est réalisée par le calcul de la moyenne annuelle dans chacune des 3 UE formant le BUT 1.
#
# UE1 : dominante réseaux
# UE2 : dominante télécoms
# UE3 : dominante programmation
# Une moyenne semestrielle est produite pour chaque ressource et chaque SAÉ.
#
# La moyenne semestrielle pour chaque UE est une moyenne de toutes les notes du semestre, pondérée par des coefficients qui dépendent de l'UE et du semestre.
#
# 📌 Accès aux valeurs des coefficients pour chacun des semestres
#
# En fin d'année :
#
# Si la moyenne sur l'année de chacune des trois UE est ≥10
#  : l'année est validée et le passage en BUT 2 est autorisé
# Si la moyenne sur l'année de 2 UE est ≥10
#  alors que la moyenne de la troisième UE est comprise entre 8 (inclus) et 10 (exclu) : l'année de BUT 1 n'est pas validée mais le passage en BUT 2 est autorisé. Il faudra alors impérativement valider cette dernière UE en BUT 2 (au niveau 2, ce qui validera automatiquement le niveau 1 )
# Si la moyenne sur l'année de 2 UE est ≥10
#  alors que la moyenne de la troisième UE est inférieure à 8 : l'année n'est pas validée et le passage en BUT 2 n'est pas autorisé. Un redoublement peut-être proposé à l'appréciation du conseil des enseignants.
# Si la moyenne sur l'année de 2 ou 3 UE est inférieure à 10 : l'année n'est pas validée et le passage en BUT est exclu.

# %% [raw]
# ⚙️ Consignes pour le travail de versionning

# %% [raw]
# - Version 1 : les calculs des moyennes des UE est réalisé avec des notes et coefficients saisis au clavier.

# %% [raw]
# algo:
# pour i allant de 101 à 104:
# demander la note de la ressource
# lire la note
# Demander le coefficent de la roussource
# lire le coeff

# %%
som_1=0
coe_1=0
moy_1=0

for i in range (101,115):
    note=float(input("Donnez-moi la note de la ressource R{}".format(i)))
    coeff=int(input("Donnez-moi le coefficient de la ressource R{}".format(i)))
    som_1+=note*coeff
    coe_1+=coeff

for i in range (11,16):
    note=float(input("Donnez-moi la note de la SAE SAE{}".format(i)))
    coeff=int(input("Donnez-moi le coefficient de la SAE SAE{}".format(i)))
    som_1+=note*coeff
    coe_1+=coeff
moy_1=som_1/coe_1
print(moy_1)

# %%
moy_1=0
coe_1=0
som_1=0
coe_2=0
som_2=0
UE=int(input("donnez-moi votre UE"))
if UE==1:
   for i in range(101,103):
       note=float(input("donnez-moi la note de la ressources R{}".format(i)))
       coeff=int(input("donnez-moi le coeff de la ressources R{}".format(i)))
       som_1+=note*coeff
       coe_1+=coeff
   for i in range (11,13):
       note=float(input("donnez-moi la note de la ressources SAE{}".format(i)))
       coeff=int(input("donnez-moi le coeff de la ressources SAE{}".format(i)))
       som_2+=note*coeff
       coe_2+=coeff
   moy_1=som_1/coe_1
   print("la moyenne de vorte UE1 et de :",moy_1)
elif UE==2:
   for i in range(101,103):
       note=float(input("donnez-moi la note de la ressources R{}".format(i)))
       coeff=int(input("donnez-moi le coeff de la ressources R{}".format(i)))
       som_1+=note*coeff
       coe_1+=coeff
   for i in range (11,13):
       note=float(input("donnez-moi la note de la ressources SAE{}".format(i)))
       coeff=int(input("donnez-moi le coeff de la ressources SAE{}".format(i)))
       som_2+=note*coeff
       coe_2+=coeff
   moy_1=som_1/coe_1
   print("la moyenne de vorte UE2 et de :",moy_1)
else:
   for i in range(101,103):
       note=float(input("donnez-moi la note de la ressources R{}".format(i)))
       coeff=int(input("donnez-moi le coeff de la ressources R{}".format(i)))
       som_1+=note*coeff
       coe_1+=coeff
   for i in range (11,13):
       note=float(input("donnez-moi la note de la ressources SAE{}".format(i)))
       coeff=int(input("donnez-moi le coeff de la ressources SAE{}".format(i)))
       som_2+=note*coeff
       coe_2+=coeff
   moy_1=som_1/coe_1
   print("la moyenne de vorte UE3 et de :",moy_1)

# %% [raw]
# - Version 2 : le calcul des moyennes des UE est réalisé avec des notes et des coefficients dans des listes.

# %%
note = (15, 7, 14, 11, 17, 10, 8)

coefs = (10, 10, 7, 7, 20, 0)
moyennes =
